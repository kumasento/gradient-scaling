# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats
import seaborn as sns

# %%
X = np.load('grad.npy')
X = X.reshape([-1])

# %%
X
# Out:
# array([5.1203908e-09, 6.0682703e-09, 8.1521296e-09, ..., 6.1487087e-09,
#        6.2052026e-09, 6.5797523e-09], dtype=float32)

# %%
log_X = np.log(np.abs(X[X != 0]))

# %%
y = plt.hist(log_X, bins=100)

# %%
plt.plot(y[1][1:], y[0])

# %%
fig, ax = plt.subplots()

Y = np.abs(X)
y_ = ax.hist(Y[Y<1e-6], bins=100)
