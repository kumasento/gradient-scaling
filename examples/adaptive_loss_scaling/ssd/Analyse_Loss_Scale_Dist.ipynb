# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# Analyse Loss Scale Distribution
# ===
#
# This notebook checks the distribution of loss scale values among all layers across the whole training procedure.

# %%
import os
import sys
import matplotlib
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.interpolate import spline
import seaborn as sns

import utils

# %%
# setup font size
matplotlib.rcParams.update({'font.size': 14})

# %% [markdown]
# ## Plot SSD 512
#
# <font color="red">
# Update the example directory.
# </font>

# %%
fig, ax = plt.subplots(figsize=(5, 4))

utils.plot_loss_scale_dist('/mnt/ccnas2/bdp/rz3515/train/ada_loss/object_detection/ssd512/ada_loss/', ax)

ax.set_xlabel('Layer ID')
ax.set_ylabel('Mean loss scale')
ax.set_title('SSD-512 Loss Scale Distribution')
# Out:
# Text(0.5, 1.0, 'SSD-512 Loss Scale Distribution')

# %% [markdown]
# ## Plot SSD 300
#
#
# <font color="red">
# Update the example directory.
# </font>

# %%
fig, ax = plt.subplots(figsize=(5, 4))

utils.plot_loss_scale_dist('/mnt/ccnas2/bdp/rz3515/train/ada_loss/object_detection/ssd300/fixed.GPU_1_scale_8.20200102', ax)

ax.set_xlabel('Layer ID')
ax.set_ylabel('Mean loss scale')
ax.set_title('SSD-300 Loss Scale Distribution')
# Out:
# Text(0.5, 1.0, 'SSD-300 Loss Scale Distribution')
